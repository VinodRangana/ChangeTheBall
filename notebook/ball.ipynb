# %%
import sys
import os
import cv2
import matplotlib.pyplot as plt

sys.path.append(os.path.abspath('..'))

from src.ball import CricketBall

ball1 = CricketBall(1,20,"../data/raw/ball_1_top.jpeg","../data/raw/ball_1_side1.jpeg","../data/raw/ball_1_side2.jpeg")

# %%
top = cv2.imread(ball1.org_img_path["top"], 0)
front = cv2.imread(ball1.org_img_path["front"],0)
side = cv2.imread(ball1.org_img_path["side"],0)

# %%
plt.subplot(131)
plt.imshow(top,"grey")

plt.subplot(132)
plt.imshow(front, "grey")

plt.subplot(133)
plt.imshow(side,"grey")
plt.show()
